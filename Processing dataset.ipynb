# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv("/content/drive/My Drive/IIITNR_PROJECT/data.csv" )

# %%
dataset
# Out:
#       dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0           24.141694         25.572342         26.011782          25.984342
# 1           25.124429         26.607912         27.314094          27.290155
# 2           25.124429         26.607912         27.314094          27.290155
# 3           24.141694         25.572342         26.011782          25.984342
# 4           21.085366         36.684982         42.747826          36.372711
# ...               ...               ...               ...                ...
# 1556        23.002656         24.306926         25.101636          25.122024
# 1557        16.966723         16.834458         16.529494          16.931054
# 1558        40.456790         43.867547         29.026246          31.113144
# 1559        20.743029         23.274921         24.465181          23.461793
# 1560        16.851758         18.363401         17.642357          15.464163
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named df
features = dataset.drop(columns=['label'])  # Extracting all features except the label

# Plot histograms for each feature
for column in features.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(features[column], kde=True)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# Plot box plots for each feature
for column in features.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=features[column])
    plt.title(f'Box Plot of {column}')
    plt.xlabel(column)
    plt.show()

# %%
# transformation
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
dataset['labeled_encoded'] = label_encoder.fit_transform(dataset['label'])

# %%
dataset
# Out:
#       dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0           24.141694         25.572342         26.011782          25.984342
# 1           25.124429         26.607912         27.314094          27.290155
# 2           25.124429         26.607912         27.314094          27.290155
# 3           24.141694         25.572342         26.011782          25.984342
# 4           21.085366         36.684982         42.747826          36.372711
# ...               ...               ...               ...                ...
# 1556        23.002656         24.306926         25.101636          25.122024
# 1557        16.966723         16.834458         16.529494          16.931054
# 1558        40.456790         43.867547         29.026246          31.113144
# 1559        20.743029         23.274921         24.465181          23.461793
# 1560        16.851758         18.363401         17.642357          15.464163
#
# ...

# %%
dataset = dataset.drop(columns=['label'])

# %%
dataset.head(10)
# Out:
#    dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0        24.141694         25.572342         26.011782          25.984342
# 1        25.124429         26.607912         27.314094          27.290155
# 2        25.124429         26.607912         27.314094          27.290155
# 3        24.141694         25.572342         26.011782          25.984342
# 4        21.085366         36.684982         42.747826          36.372711
# 5        20.495122         21.620879         19.720870          20.979853
# 6        24.960976         24.673077         24.311304          24.863553
# 7        24.538893         24.777273         24.445312          24.529091
# 8        20.357955         19.826389         19.818182          21.215278
# 9        38.795935         41.181319         39.669565          39.443223
#
#    correlation_0  correlation_45  correlation_90  correlation_135  \
# 0       0.160142        0.072171        0.041680         0.042701
# ...

# %%
dataset['labeled_encoded'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
dataset.tail(10)
# Out:
#       dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 1551        49.512821         51.840179         50.290404          50.291071
# 1552        19.639423         19.677180         19.348607          19.042672
# 1553        17.950801         28.589491         29.829662          28.082512
# 1554        57.992832         64.290971         58.715203          55.437954
# 1555        31.174012         33.249514         34.596284          35.169053
# 1556        23.002656         24.306926         25.101636          25.122024
# 1557        16.966723         16.834458         16.529494          16.931054
# 1558        40.456790         43.867547         29.026246          31.113144
# 1559        20.743029         23.274921         24.465181          23.461793
# 1560        16.851758         18.363401         17.642357          15.464163
#
#       correlation_0  correlation_45  correlation_90  correlation_135  \
# ...

# %%
dataset.drop(columns=['label', 'labeled_encoded'], inplace=True)

# %%
dataset
# Out:
#       dissimilarity_0  dissimilarity_45  dissimilarity_90  dissimilarity_135  \
# 0           24.141694         25.572342         26.011782          25.984342
# 1           25.124429         26.607912         27.314094          27.290155
# 2           25.124429         26.607912         27.314094          27.290155
# 3           24.141694         25.572342         26.011782          25.984342
# 4           21.085366         36.684982         42.747826          36.372711
# ...               ...               ...               ...                ...
# 1556        23.002656         24.306926         25.101636          25.122024
# 1557        16.966723         16.834458         16.529494          16.931054
# 1558        40.456790         43.867547         29.026246          31.113144
# 1559        20.743029         23.274921         24.465181          23.461793
# 1560        16.851758         18.363401         17.642357          15.464163
#
# ...

# %%
def correlation(data , threshold):
  col_corr = set()
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
col_feature = correlation(dataset , 0.9)

# %%
len(set(col_feature))
# Out:
# 17

# %%
col_feature
# Out:
# {'ASM_135',
#  'ASM_45',
#  'ASM_90',
#  'contrast_0',
#  'contrast_135',
#  'contrast_45',
#  'contrast_90',
#  'dissimilarity_135',
#  'dissimilarity_45',
#  'dissimilarity_90',
#  'energy_0',
#  'energy_135',
#  'energy_45',
#  'energy_90',
#  'homogeneity_135',
#  'homogeneity_45',
#  'homogeneity_90'}

# %%
|dataset.to_csv("/content/drive/My Drive/IIITNR_PROJECT/processed_data.csv")
